# %%
from langchain.agents.agent_toolkits import GmailToolkit

toolkit = GmailToolkit()

# tools = toolkit.get_tools()
# print(tools)

import os

os.environ["OPENAI_API_KEY"] = "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"

from langchain import OpenAI
from langchain.agents import initialize_agent, AgentType

llm = OpenAI(temperature=0)

agent = initialize_agent(
    tools=GmailToolkit().get_tools(),
    llm=llm,
    agent=AgentType.STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION,
)

# print(agent.run("send email message to sankalpwaghe123@gmail.com that you have passed in Maths"))

# choice = input(
#     "Enter 1 to send an email to A,\n 2 to send an email to B,\n or any other key to send an email to C: "
# )

# %%
from langchain.agents.agent_toolkits import GmailToolkit

toolkit = GmailToolkit()

# tools = toolkit.get_tools()
# print(tools)

import os

os.environ["OPENAI_API_KEY"] = "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"

from langchain import OpenAI
from langchain.agents import initialize_agent, AgentType

llm = OpenAI(temperature=0)

agent = initialize_agent(
    tools=GmailToolkit().get_tools(),
    llm=llm,
    agent=AgentType.STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION,
)

# print(agent.run("send email message to sankalpwaghe123@gmail.com that you have passed in Maths"))

# choice = input(
#     "Enter 1 to send an email to A,\n 2 to send an email to B,\n or any other key to send an email to C: "
# )



from langchain import PromptTemplate

# llm = OpenAI(model_name="text-davinci-003", openai_api_key=openai_api_key)

# Notice "weight" below, that is a placeholder for another value later
template = """
If your weight is below 50 then show Underweight
If your weight is between 51-100 then show Moderate
if weight is above 100 then show Overweight
weight is {weight}
"""

prompt = PromptTemplate(
    input_variables=["weight"],
    template=template,
)
# person_weight=60
final_prompt = prompt.format(weight=eval(input("weight")))
print(f"Final Prompt: {final_prompt}")
print("-----------")
print(f"LLM Output: {llm(final_prompt)}")

# uncomment to send mail
# agent.run(
#     "create an email BMI and send it to sankalpwaghe123@gmail.com and your Weight is : {weight}"
# )
# Out:
# Final Prompt:
# If your weight is below 50 then show Underweight
# If your weight is between 51-100 then show Moderate
# if weight is above 100 then show Overweight
# weight is 34
#
# -----------
# LLM Output: Underweight
